# %% [markdown]
# # Aspectos de Ciência de Dados 👨🏽‍🔬

# %% [markdown]
# ## Sumário da Aula

# %% [markdown]
# <ul>
#     <li>Cronologia ⏱️</li>
#     <li>Conhecimentos e Habilidades do Cientista de Dados 👩‍💻</li>
#     <li>Hype 🌊 ou Hope 🙏</li>
# </ul>

# %% [markdown]
# ## Cronologia ⏱️

# %% [markdown]
# <ul>
#     <li>1962: John Tukey descreveu um campo que chamou de "análise de dados" -- que se assemelha à atual ciência de dados;</li>
#     <li>1974: Peter Naur propôs "ciência de dados" como um nome alternativo para "ciência da computação";</li>
#     <li>1985: C. F. Jeff Wu usou o termo "ciência de dados" pela primeira vez como um nome alternativo para "estatística";</li>
#     <li>1989: Gregory Piatetsky-Shapiro organiza e preside o primeiro workshop Knowledge Discovery in Databases (KDD) <br />-- renomeado em 1995 para Knowledge Discovery and Data Mining;</li>
#     <li>2001: William S. Cleveland defendeu uma expansão da estatística além da teoria para áreas técnicas <br />-- porque isso mudaria significativamente a área, justificaria um novo nome: ciência de dados;</li>
#     <li>2012: Thomas H. Davenport e D. J. Patil declararam "Cientista de Dados: O Trabalho Mais Sexy do Século XXI";</li>
#     <li>2022: <a href='https://hbr.org/2022/07/is-data-scientist-still-the-sexiest-job-of-the-21st-century'>Is Data Scientist Still the Sexiest Job of the 21st Century?</a>
# </ul>

# %% [markdown]
# <table align='left'>
#     <tr align='center'>
#         <td>John Tukey</td>
#         <td>Peter Naur</td>
#         <td>C. F. Jeff Wu</td>
#         <td>Gregory Piatetsky Shapiro</td>
#         <td>William S. Cleveland</td>
#         <td>Tom H. Davenport</td>
#         <td>D. J. Patil</td>
#     </tr>
#     <tr align='center'>
#         <td><img src='https://upload.wikimedia.org/wikipedia/en/e/e9/John_Tukey.jpg' width=150></td>
#         <td><img src='https://upload.wikimedia.org/wikipedia/commons/5/55/Peternaur.JPG' width=150></td>
#         <td><img src='https://upload.wikimedia.org/wikipedia/commons/f/f7/C.F._Jeff_Wu_at_Chinese_Academy_of_Sciences_2011.JPG' width=150></td>
#         <td><img src='https://littleml.files.wordpress.com/2013/08/gregory-piatetsky.jpg' width=150></td>
#         <td><img src='https://media.science.purdue.edu/uploads/statcentral/4ae9fc7f2641b23b544101ed571320c17ed276b200346712d5a1ef73cecf0a4e.jpg' width=150></td>
#         <td><img src='https://www.tomdavenport.com/wp-content/uploads/2019/04/tom-davenport-125x170.png' width=150></td>
#         <td><img src='https://upload.wikimedia.org/wikipedia/commons/8/85/DJ_Patil_in_2021_by_Christopher_Michel.jpg' width=150></td>
#     </tr>
# </table>

# %% [markdown]
# ### Linha do Tempo

# %% [markdown]
# <img src='https://www.datascienceassn.org/sites/default/files/users/user30/History%20of%20Data-Science.png'>

# %% [markdown]
# ## Conhecimentos e Habilidades do Cientista de Dados 👩‍💻

# %% [markdown]
# ### Conhecimentos

# %% [markdown]
# <img src='https://dceg.cancer.gov/sites/g/files/xnrzdm236/files/styles/cgov_enlarged/public/cgov_image/media_image/2022-03/data%20science%20venn%20diagram.png' style='float:left;width:250px;'>
# "Data Science is the field that brings together domain data, computer science, and the statistical tools for interrogating the data and extracting useful information."
# <ul>
#     <li>Os especialistas do domínio entendem seus dados e talvez saibam o que podem esperar aprender com os dados.</li>
#     <li>Os estatísticos trazem experiência em análise de dados, coleta de dados, modelagem e inferência</li>
#     <li>Os cientistas da computação trazem métodos para armazenamento confiável, para proteger a privacidade e a integridade dos dados, bem como experiência na aplicação de computação de alto desempenho e sistemas em rede para computação eficiente.</li>
# </ul>

# %% [markdown]
# 👉 referência <a href='https://dstf.acm.org/DSTF_Final_Report.pdf'>acm.org</a>
#
# 🚨 dedique um tempo para conhecer o currículo sugerido para cursos de ciência de dados em 2021 -- referência acima 🚨

# %% [markdown]
# ### Habilidades

# %% [markdown]
# Top 10 Habilidades dos Cientistas de Dados, nos EUA, em 2022:
# <ol>
#     <li>Machine Learning</li>
#     <li>Data Science</li>
#     <li>Natural Language Processing (NLP)</li>
#     <li>SQL</li>
#     <li>Python (Programming Language)</li>
#     <li>Data Visualization</li>
#     <li>Deep Learning</li>
#     <li>Pandas (Software)</li>
#     <li>Predictive Modeling</li>
#     <li>R (Programming Language)</li>
# </ol>

# %% [markdown]
# 👉 Vamos investir um tempo explorando o LinkedIn’s Economic Graph: <a href='https://linkedin.github.io/future-of-skills/'>The future of skills</a>

# %% [markdown]
# ### Atitude

# %% [markdown]
# <pre>Growth mindset</pre>

# %% [markdown]
# <img src='https://bettereveryday840.files.wordpress.com/2018/06/picture1.png' style='float:right;width:200px;'>
#
# <ol>
#     <li>A ‘zona de conforto’ é onde a maioria das pessoas passa a maior parte do tempo no trabalho. <br />O trabalho pode ser complicado ou complexo, mas não é difícil, desafiador ou novo;</li>
#     <li>A 'zona de crescimento' é onde uma pessoa precisa se adaptar e aprender novas habilidades e, <br />embora seja desafiadora e desconfortável, ela pode progredir;</li>
#     <li>A 'zona de pânico' é onde a situação é tão diferente ou estressante que <br />está além da capacidade de uma pessoa lidar.</li>
# </ol>

# %% [markdown]
# <img src='https://bettereveryday840.files.wordpress.com/2018/06/picture11.png' style='float:left;width:350px;'>
#
# quando você se expõe repetidamente, em pequenas doses, você pode aumentar sua tolerância
#
# 🚨 permite que pessoas lidem com maior estresse --
#
# aumentando as zonas de conforto e crescimento

# %% [markdown]
# <img src='https://bettereveryday840.files.wordpress.com/2018/06/picture22.png' style='float:left;width:350px;'>
#
# quando você não se expõe, você pode diminuir sua tolerância
#
# 🚨 torna pessoas menos capazes de lidar com choques repentinos --
#
# reduzindo capacidade de desenvolver novas habilidades ou assumir novas responsabilidades

# %% [markdown]
# <img src='https://bettereveryday840.files.wordpress.com/2018/06/picture3.png' style='float:left;width:350px;'>
#
# quando você se expõe demais, pode ser levado à zona de pânico
#
# 🚨 o estresse pode se manifestar em sintomas físicos ou mentais --
#
# reduzindo capacidade de tomar decisão e encolhendo suas zonas de crescimento e conforto

# %% [markdown]
# 👉 referência: <a href='https://gettingbettereveryday.org/2018/07/12/leadership-hack-020-explaining-personal-growth-to-your-reports/'>gettingbettereveryday.org</a>

# %%
from IPython.display import YouTubeVideo
YouTubeVideo(id='_X0mgOOSpLU')

# %% [markdown]
# ## Hype 🌊 ou Hope 🙏

# %% [markdown]
# <table>
#     <tr><th>Hype ou Hope?</th><th>Hope ou Hype?</th>
#     <tr><td><img src='https://deepsense.ai/wp-content/uploads/2019/02/five-trends-for-business-to-surf-the-big-data-wave-1140x337.png' width=500></td><td><img src='https://evergreengavekal.com/wp-content/uploads/IoT3.jpg' width=300></td></tr>
# </table>

# %% [markdown]
# <pre>“Jobs on the Rise” are defined as the career categories that have seen the highest year-over-year growth rates in hiring (as reflected in the April 2020 to October 2020 timeframe). </pre>

# %% [markdown]
# > "According to the 2020 U.S. Emerging Jobs Report, data roles, specifically data scientist and data engineer roles, are increasing steadily — reflecting about a 35% average annual growth for both roles."
#
# > "Demand is strong for tech professionals with artificial intelligence experience. In fact, this was the top emerging job trend from last year’s report."

# %% [markdown]
# 👉 referência: <a href='https://business.linkedin.com/talent-solutions/emerging-jobs-report'>business.linkedin.com</a>

# %% [markdown]
# ## Extra! Map of Science -- para geeks 🤓

# %%
from IPython.display import YouTubeVideo
YouTubeVideo(id='SzJ46YA_RaA', width='100%')

# %%
from IPython.display import YouTubeVideo
YouTubeVideo(id='OmJ-4B-mS-Y', width='100%')

# %%
from IPython.display import YouTubeVideo
YouTubeVideo(id='ohyai6GIRZg', width='100%')
